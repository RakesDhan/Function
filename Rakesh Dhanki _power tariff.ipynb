# %% [markdown]
# ## Power Tariff calculator

# %%
## https://ebcalculator.com/bill/west-bengal-electricity-bill-calculator-per-unit-rate-tariff-order/

'''
Total electricity bill=Meter rent cost+((Fixed cost per kva of connected load)*(no. of units of KVA)*(kVA rating))
                       +((no of units (kwh)consumed)*(variable cost per kwh or unit))
'''                       

unit=int(input("Enter the unit consumed: "))
ct= str(input("enter the type of consumer Domestic or Commercial:"))
ar=str(input("enter the area  of consumer Rural or Urban:"))

def Bill_Calc1(unit,ct,ar):
    if ct=="Domestic" and ar=="Rural":
        kva=int(input("Enter the kva or demand:"))
        fixed_charge_domestic_Rs_per_kva_per_month=30
        fc=fixed_charge_domestic_Rs_per_kva_per_month *kva
        meter_rent_Rs_per_month =10
        mr= meter_rent_Rs_per_month
        if((unit>=1)and(unit<=100)):
            print("your electricity bill for this month is:")
            print(fc+mr+(unit*5));
    
        elif((unit>100)and(unit<=180)):
            print("your electricity bill for this month is:")
            print(fc+mr+(100*5)+((unit-100)*6.24))
    
        elif((unit>180)and(unit<=300)):
            print("your electricity bill for this month is:")
            print(fc+mr+(100*5)+((180-100)*6.24)+((unit-180)*6.89))
    
        elif(unit>300) and (unit<=600):
            print("your electricity bill for this month is:")
            print(fc+mr+(100*5)+((180-100)*6.24)+((300-180)*6.89)+((unit-300)*7.44))
                
        elif(unit>600) and (unit<=900):
            print("your electricity bill for this month is:")
            print(fc+mr+(100*5)+((180-100)*6.24)+((300-180)*6.89)+((600-300)*7.44)+((unit-600)*7.43))
            
        elif(unit>900):
            print("your electricity bill for this month is:")
            print(fc+mr+(100*5)+((180-100)*6.24)+((300-180)*6.89)+((600-300)*7.44)+((900-600)*7.43)+((unit-900)*9.22))
        else:
            print("No usage ")
            print("your electricity bill for this month is:")
            print(fc+mr)
        
    elif ct=="Domestic" and ar=="Urban":
        kva=int(input("Enter the kva or demand:"))
        fixed_charge_domestic_Rs_per_kva_per_month=30
        fc=fixed_charge_domestic_Rs_per_kva_per_month *kva
        meter_rent_Rs_per_month =10
        mr= meter_rent_Rs_per_month
        if((unit>=1)and(unit<=100)):
            print("your electricity bill for this month is:")
            print(fc+mr+(unit*5.03))
    
        elif((unit>100)and(unit<=180)):
            print("your electricity bill for this month is:")
            print(fc+mr+(100*5.03)+((unit-100)*6.33))
    
        elif((unit>180)and(unit<=300)):
            print("your electricity bill for this month is:")
            print(fc+mr+(100*5.03)+((180-100)*6.33)+((unit-180)*7.12))
    
        elif(unit>300) and (unit<=600): 
            print("your electricity bill for this month is:")
            print(fc+mr+(100*5.03)+((180-100)*6.33)+((300-180)*7.12)+((unit-300)*7.52))
                
        elif(unit>600) and (unit<=900):
            print("your electricity bill for this month is:")
            print(fc+mr+(100*5.03)+((180-100)*6.33)+((300-180)*7.12)+((600-300)*7.52)+((unit-600)*7.69))
                
        elif(unit>900):
            print("your electricity bill for this month is:")
            print(fc+mr+(100*5.03)+((180-100)*6.33)+((300-180)*7.12)+((600-300)*7.52)+((900-600)*7.69)+((unit-900)*9.22))
        else:
            print("No usage ")
            print("your electricity bill for this month is:")
            print(fc+mr)
                
    elif ct=="Commercial" and ar=="Rural":
        kva=int(input("Enter the kva or demand:"))
        fixed_charge_domestic_Rs_per_kva_per_month=60
        fc=fixed_charge_domestic_Rs_per_kva_per_month *kva
        meter_rent_Rs_per_month =20
        mr= meter_rent_Rs_per_month
        if((unit>=1)and(unit<=180)):
            print("your electricity bill for this month is:")
            print(fc+mr+(unit*5.75));
    
        elif((unit>180)and(unit<=300)):
            print("your electricity bill for this month is:")
            print(fc+mr+(180*5.75)+((unit-180)*7.5))
    
        elif(unit>300) and (unit<=600):
            print("your electricity bill for this month is:")
            print(fc+mr+(180*5.75)+((300-180)*7.5)+((unit-300)*8.2))
                
        elif(unit>600) and (unit<=900):
            print("your electricity bill for this month is:")
            print(fc+mr+(180*5.75)+((300-180)*7.5)+((600-300)*8.2)+((unit-600)*8.51))
        elif(unit>900):
            print("your electricity bill for this month is:")
            print(fc+mr+(180*5.75)+((300-180)*7.5)+((600-300)*8.2)+((900-600)*8.51)+((unit-900)*9.02))
            
        else:
            print("No usage ")
            print("your electricity bill for this month is:")
            print(fc+mr)
                
    elif ct=="Commercial" and ar=="Urban":
        kva=int(input("Enter the kva or demand:"))
        fixed_charge_domestic_Rs_per_kva_per_month=60
        fc=fixed_charge_domestic_Rs_per_kva_per_month *kva
        meter_rent_Rs_per_month =20
        mr= meter_rent_Rs_per_month
        if((unit>=1)and(unit<=180)):
            print("your electricity bill for this month is:")
            print(fc+mr+(unit*5.77))
    
        elif((unit>180)and(unit<=300)):
            print("your electricity bill for this month is:")
            print(fc+mr+(180*5.77)+((unit-180)*7.52))
    
        elif(unit>300) and (unit<=600):
            print("your electricity bill for this month is:")
            print(fc+mr+(180*5.77)+((300-180)*7.52)+((unit-300)*8.2))
                
        elif(unit>600) and (unit<=900):
            print("your electricity bill for this month is:")
            print(fc+mr+(180*5.77)+((300-180)*7.52)+((600-300)*8.2)+((unit-600)*8.51))
        elif(unit>900):
            print("your electricity bill for this month is:")
            print(fc+mr+(180*5.77)+((300-180)*7.52)+((600-300)*8.2)+((900-600)*8.51)+((unit-900)*9.02))
        else:
            print("No usage ")
            print("your electricity bill for this month is:")
            print(fc+mr)
    
    

Bill_Calc1(unit,ct,ar)
# Out:
# Enter the unit consumed: 150
# enter the type of consumer Domestic or Commercial:Domestic
# enter the area  of consumer Rural or Urban:Rural
# Enter the kva or demand:1
# your electricity bill for this month is:
# 852.0
